# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
FuerzaTot = np.genfromtxt('FuerzaTot.dat', delimiter=' ', usecols=(0, 1))

# Realizar regresión lineal
z = np.polyfit(FuerzaTot[:,0], np.abs(FuerzaTot[:,1]), 1)
p = np.poly1d(z)

# Obtener pendiente y punto de corte
pendiente = z[0]
punto_corte = z[1]

print(f"Pendiente: {pendiente:.4f}")
print(f"Punto de corte: {punto_corte:.4f}")

# Plotear datos y regresión lineal
plt.plot(FuerzaTot[:,0], np.abs(FuerzaTot[:,1]), 'o', label='Datos')
plt.plot(FuerzaTot[:,0],p(FuerzaTot[:,0]), '-', label='Regresión lineal')
plt.xlabel(r'$\omega$')
plt.ylabel(r'$F_{x}$')
plt.grid(color='#c0c0c0', linewidth=1,alpha=0.5)
plt.minorticks_on()
plt.legend()
plt.show()
# Out:
# Pendiente: 54.3312
# Punto de corte: 0.7999

# %%
FuerzaY = np.genfromtxt('FuerzaY.dat', delimiter=' ', usecols=(0, 1))

# Realizar regresión lineal
z = np.polyfit(FuerzaY[:,0], np.abs(FuerzaY[:,1]), 1)
p = np.poly1d(z)

# Obtener pendiente y punto de corte
pendiente = z[0]
punto_corte = z[1]

print(f"Pendiente: {pendiente:.4f}")
print(f"Punto de corte: {punto_corte:.4f}")

# Plotear datos y regresión lineal
plt.plot(FuerzaY[:,0], np.abs(FuerzaY[:,1]), 'o', label='Datos')
plt.plot(FuerzaY[:,0],p(FuerzaY[:,0]), '-', label='Regresión lineal')
plt.xlabel(r'$\omega$')
plt.ylabel(r'$F_{y}$')
plt.grid(color='#c0c0c0', linewidth=1,alpha=0.5)
plt.minorticks_on()
plt.legend()
plt.show()
# Out:
# Pendiente: 27.3002
# Punto de corte: 0.3037

# %%
FuerzaX = np.genfromtxt('FuerzaX.dat', delimiter=' ', usecols=(0, 1))

# Realizar regresión lineal
z = np.polyfit(FuerzaX[:,0], np.abs(FuerzaX[:,1]), 1)
p = np.poly1d(z)

# Obtener pendiente y punto de corte
pendiente = z[0]
punto_corte = z[1]

print(f"Pendiente: {pendiente:.4f}")
print(f"Punto de corte: {punto_corte:.4f}")

# Plotear datos y regresión lineal
plt.plot(FuerzaX[:,0], np.abs(FuerzaX[:,1]), 'o', label='Datos')
plt.plot(FuerzaX[:,0],p(FuerzaX[:,0]), '-', label='Regresión lineal')
plt.xlabel(r'$\omega$')
plt.ylabel(r'$F_{y}$')
plt.grid(color='#c0c0c0', linewidth=1,alpha=0.5)
plt.minorticks_on()
plt.legend()
plt.show()
# Out:
# Pendiente: 55.2756
# Punto de corte: 0.5300

# %%
print(2*np.pi/1000)
# Out:
# 0.006283185307179587

# %%
FuerzasYPrueba = np.genfromtxt('FuerzasYPrueba.dat', delimiter=' ', usecols=(0, 1))

# Realizar regresión lineal
z = np.polyfit(FuerzasYPrueba[:,0], np.abs(FuerzasYPrueba[:,1]), 1)
p = np.poly1d(z)

# Obtener pendiente y punto de corte
pendiente = z[0]
punto_corte = z[1]

print(f"Pendiente: {pendiente:.4f}")
print(f"Punto de corte: {punto_corte:.4f}")

# Plotear datos y regresión lineal
plt.plot(FuerzasYPrueba[:,0], np.abs(FuerzasYPrueba[:,1]), 'o', label='Datos')
plt.plot(FuerzasYPrueba[:,0],p(FuerzasYPrueba[:,0]), '-', label='Regresión lineal')
plt.xlabel(r'$\omega$')
plt.ylabel(r'$F_{y}$')
plt.grid(color='#c0c0c0', linewidth=1,alpha=0.5)
plt.minorticks_on()
plt.legend()
plt.show()
# Out:
# Pendiente: 46.3438
# Punto de corte: 0.0439
