# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
Valores_reales = np.loadtxt('Fuentes/fuente_1.txt', delimiter=' ')
#Perfil_velocidades2 = np.genfromtxt('Ondas3DSegunda.dat', delimiter=' ', usecols=(0, 1))
valores_simualdos=np.loadtxt("Data.txt")
VS_dB=20*np.log10(valores_simualdos[:,1]/2e-6)

#plt.plot(20e-6*10**(Valores_reales/20),label="reales dBa", alpha=0.5)
#plt.plot(VS_dB,label="reales dBa", alpha=0.5)
plt.plot(valores_simualdos[:,0],valores_simualdos[:,1],label="presion", alpha=0.5)
#plt.plot(Perfil_velocidades2[:,0],Perfil_velocidades2[:,1],'o-', color='Red', alpha=0.5)
plt.xlabel(r'$segundos$')
plt.ylabel(r'$presion$')
plt.grid(color='#c0c0c0', linewidth=1,alpha=0.5)
plt.legend()
plt.minorticks_on()
plt.show()
# Out:
# /tmp/ipykernel_67773/1219318476.py:4: RuntimeWarning: divide by zero encountered in log10
#   VS_dB=20*np.log10(valores_simualdos[:,1]/2e-6)
# /tmp/ipykernel_67773/1219318476.py:4: RuntimeWarning: invalid value encountered in log10
#   VS_dB=20*np.log10(valores_simualdos[:,1]/2e-6)

# %%
Valores_reales = np.loadtxt('Fuentes/fuente_1.txt', delimiter=' ')
#Perfil_velocidades2 = np.genfromtxt('Ondas3DSegunda.dat', delimiter=' ', usecols=(0, 1))
valores_simualdos=np.loadtxt("Data.txt")
VS_dB=20*np.log10(valores_simualdos[:,1]/2e-6)

plt.plot(Valores_reales,label="reales dBa", alpha=0.5)
#plt.plot(VS_dB,label="reales dBa", alpha=0.5)
#plt.plot(valores_simualdos[:,1],label="presion", alpha=0.5)
#plt.plot(Perfil_velocidades2[:,0],Perfil_velocidades2[:,1],'o-', color='Red', alpha=0.5)
plt.xlabel(r'$pasos$')
plt.ylabel(r'$presion$')
plt.grid(color='#c0c0c0', linewidth=1,alpha=0.5)
plt.legend()
plt.minorticks_on()
plt.show()
# Out:
# /tmp/ipykernel_67773/3026428990.py:4: RuntimeWarning: divide by zero encountered in log10
#   VS_dB=20*np.log10(valores_simualdos[:,1]/2e-6)
# /tmp/ipykernel_67773/3026428990.py:4: RuntimeWarning: invalid value encountered in log10
#   VS_dB=20*np.log10(valores_simualdos[:,1]/2e-6)

# %%
plt.plot(valores_simualdos[1000:,0],VS_dB[1000:])

# %%
Ondas2D = np.genfromtxt('Ondas.dat', delimiter=' ', usecols=(0, 1))
plt.plot(Ondas2D[:,0],Ondas2D[:,1],'-', color='Red', alpha=0.5)
plt.xlabel(r'$x$')
plt.ylabel(r'$p$')
plt.grid(color='#c0c0c0', linewidth=1,alpha=0.5)
plt.minorticks_on()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 Ondas2D = np.genfromtxt('Ondas.dat', delimiter=' ', usecols=(0, 1))
#       2 plt.plot(Ondas2D[:,0],Ondas2D[:,1],'-', color='Red', alpha=0.5)
#       3 plt.xlabel(r'$x$')
#
# File ~/.local/lib/python3.10/site-packages/numpy/lib/npyio.py:1980, in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows, encoding, ndmin, like)
#    1978     fname = os_fspath(fname)
#    1979 if isinstance(fname, str):
# -> 1980     fid = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#    1981     fid_ctx = contextlib.closing(fid)
#    1982 else:
#
# ...
